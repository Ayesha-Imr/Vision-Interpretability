# %%
# !pip -q install webdataset huggingface_hub
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.0/75.0 kB 5.1 MB/s eta 0:00:00

# %%
pip install torch-lucent
# Out:
# Collecting torch-lucent
#   Downloading torch_lucent-0.1.8-py3-none-any.whl.metadata (6.1 kB)
# Requirement already satisfied: torch>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from torch-lucent) (2.10.0+cu128)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (from torch-lucent) (0.25.0+cu128)
# Collecting kornia<=0.4.1 (from torch-lucent)
#   Downloading kornia-0.4.1-py2.py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from torch-lucent) (4.67.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from torch-lucent) (2.0.2)
# Requirement already satisfied: ipython in /usr/local/lib/python3.12/dist-packages (from torch-lucent) (7.34.0)
# Requirement already satisfied: pillow in /usr/local/lib/python3.12/dist-packages (from torch-lucent) (11.3.0)
# Requirement already satisfied: future in /usr/local/lib/python3.12/dist-packages (from torch-lucent) (1.0.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.12/dist-packages (from torch-lucent) (4.4.2)
# Requirement already satisfied: pytest in /usr/local/lib/python3.12/dist-packages (from torch-lucent) (8.4.2)
# Collecting pytest-mock (from torch-lucent)
#   Downloading pytest_mock-3.15.1-py3-none-any.whl.metadata (3.9 kB)
# Collecting coverage (from torch-lucent)
#   Downloading coverage-7.13.4-cp312-cp312-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl.metadata (8.5 kB)
# Collecting coveralls (from torch-lucent)
#   Downloading coveralls-4.0.2-py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from torch-lucent) (1.6.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=1.5.0->torch-lucent) (3.24.2)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.5.0->torch-lucent) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.5.0->torch-lucent) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.5.0->torch-lucent) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.5.0->torch-lucent) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.5.0->torch-lucent) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.5.0->torch-lucent) (2025.3.0)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.5.0->torch-lucent) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=1.5.0->torch-lucent) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.5.0->torch-lucent) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.5.0->torch-lucent) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1.5.0->torch-lucent) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.5.0->torch-lucent) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch>=1.5.0->torch-lucent) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.5.0->torch-lucent) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.5.0->torch-lucent) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=1.5.0->torch-lucent) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.5.0->torch-lucent) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.5.0->torch-lucent) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.5.0->torch-lucent) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.5.0->torch-lucent) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=1.5.0->torch-lucent) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.5.0->torch-lucent) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.5.0->torch-lucent) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch>=1.5.0->torch-lucent) (1.3.4)
# Collecting docopt<0.7.0,>=0.6.1 (from coveralls->torch-lucent)
#   Downloading docopt-0.6.2.tar.gz (25 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: requests<3.0.0,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from coveralls->torch-lucent) (2.32.4)
# Collecting jedi>=0.16 (from ipython->torch-lucent)
#   Downloading jedi-0.19.2-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.12/dist-packages (from ipython->torch-lucent) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.12/dist-packages (from ipython->torch-lucent) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from ipython->torch-lucent) (3.0.52)
# Requirement already satisfied: pygments in /usr/local/lib/python3.12/dist-packages (from ipython->torch-lucent) (2.19.2)
# Requirement already satisfied: backcall in /usr/local/lib/python3.12/dist-packages (from ipython->torch-lucent) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.12/dist-packages (from ipython->torch-lucent) (0.2.1)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.12/dist-packages (from ipython->torch-lucent) (4.9.0)
# Requirement already satisfied: iniconfig>=1 in /usr/local/lib/python3.12/dist-packages (from pytest->torch-lucent) (2.3.0)
# Requirement already satisfied: packaging>=20 in /usr/local/lib/python3.12/dist-packages (from pytest->torch-lucent) (26.0)
# Requirement already satisfied: pluggy<2,>=1.5 in /usr/local/lib/python3.12/dist-packages (from pytest->torch-lucent) (1.6.0)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->torch-lucent) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->torch-lucent) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->torch-lucent) (3.6.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.12/dist-packages (from jedi>=0.16->ipython->torch-lucent) (0.8.6)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.12/dist-packages (from pexpect>4.3->ipython->torch-lucent) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->torch-lucent) (0.6.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=1.0.0->coveralls->torch-lucent) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=1.0.0->coveralls->torch-lucent) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=1.0.0->coveralls->torch-lucent) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=1.0.0->coveralls->torch-lucent) (2026.1.4)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.5.0->torch-lucent) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.5.0->torch-lucent) (3.0.3)
# Downloading torch_lucent-0.1.8-py3-none-any.whl (46 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.1/46.1 kB 5.2 MB/s eta 0:00:00
# Downloading kornia-0.4.1-py2.py3-none-any.whl (225 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 225.1/225.1 kB 18.0 MB/s eta 0:00:00
# Downloading coverage-7.13.4-cp312-cp312-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl (254 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 254.1/254.1 kB 24.5 MB/s eta 0:00:00
# Downloading coveralls-4.0.2-py3-none-any.whl (13 kB)
# Downloading pytest_mock-3.15.1-py3-none-any.whl (10 kB)
# Downloading jedi-0.19.2-py2.py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 83.1 MB/s eta 0:00:00
# Building wheels for collected packages: docopt
#   Building wheel for docopt (setup.py) ... done
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13706 sha256=dc42e06c7e2e9059aab0cfc7b6e8e77bdb52497ba9334f7320ff6c97f9dc50cf
#   Stored in directory: /root/.cache/pip/wheels/1a/bf/a1/4cee4f7678c68c5875ca89eaccf460593539805c3906722228
# Successfully built docopt
# Installing collected packages: docopt, jedi, coverage, pytest-mock, coveralls, kornia, torch-lucent
# Successfully installed coverage-7.13.4 coveralls-4.0.2 docopt-0.6.2 jedi-0.19.2 kornia-0.4.1 pytest-mock-3.15.1 torch-lucent-0.1.8

# %%
import torch
import numpy as np
import heapq
from PIL import Image
import matplotlib.pyplot as plt
import os, re
import webdataset as wds
from lucent.modelzoo import inceptionv1
from lucent.optvis import render, param, transform, objectives
import pickle as pkl

# %%
from huggingface_hub import notebook_login
notebook_login()
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
#Enter your HuggingFace Token here
HF_TOKEN = "_"
os.environ["HF_TOKEN"] = HF_TOKEN
print("HF_TOKEN len:", len(os.environ["HF_TOKEN"]))
# Out:
# HF_TOKEN len: 37

# %%
import os, webdataset as wds
from torch.utils.data import DataLoader
from torchvision import transforms

# preprocessing (same as before)
preprocess = transforms.Compose([
    transforms.Resize(256),
    transforms.CenterCrop(224),
    transforms.ToTensor(),
    transforms.Normalize([0.485,0.456,0.406],[0.229,0.224,0.225]),
])

def to_tensor(sample):
    img = sample.get("jpg") or sample.get("jpeg") or sample.get("JPEG")
    if img is None:
        return None  # will be dropped below
    key = sample.get("__key__", "")
    return preprocess(img), key

base = "https://huggingface.co/datasets/timm/imagenet-1k-wds/resolve/main/"
# train shards are 0000..1023 for this repo (1024 shards total)
train_shards = [f"{base}imagenet1k-train-{i:04d}.tar?download=true" for i in range(1024)]

URLS_TRAIN = [
    "pipe:curl -f -sSL --retry 20 --retry-delay 2 "
    "-H \"Authorization: Bearer $HF_TOKEN\" "
    f"\"{u}\""
    for u in train_shards
]

dataset_train = (
    wds.WebDataset(URLS_TRAIN, handler=wds.handlers.warn_and_continue)
      .decode("pil", handler=wds.handlers.warn_and_continue)
      .map(to_tensor, handler=wds.handlers.warn_and_continue)
      .select(lambda x: x is not None)
)

dl_train = DataLoader(dataset_train, batch_size=128, num_workers=0, pin_memory=False)
# Out:
# /usr/local/lib/python3.12/dist-packages/webdataset/compat.py:379: UserWarning: WebDataset(shardshuffle=...) is None; set explicitly to False or a number
#   warnings.warn("WebDataset(shardshuffle=...) is None; set explicitly to False or a number")

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model = inceptionv1(pretrained=True).to(device).eval()
# Out:
# Downloading: "https://github.com/ProGamerGov/pytorch-old-tensorflow-models/raw/master/inception5h.pth" to /root/.cache/torch/hub/checkpoints/inception5h.pth
# 100%|██████████| 27.0M/27.0M [00:00<00:00, 379MB/s]

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# Configurations
# Kindly change the LAYER_NAME and CHANNEL_START, CHANNEL_END according to your respective responsibility

CFG = {
    "LAYER_NAME": "mixed4e",
    "CHANNEL_START": 0,
    "CHANNEL_END": 832,
    "TOPK": 10,
    "HEAP_BATCH": 20,
    "REDUCTION": "max",
    "OUT_ROOT" : "/content/drive/MyDrive/Dataset_images",
    "CROP_FRAC": 0.25,
}

# %%
# Image helpers
mean = torch.tensor([0.485, 0.456, 0.406]).view(3,1,1)
std  = torch.tensor([0.229, 0.224, 0.225]).view(3,1,1)

def tensor_to_pil(x: torch.Tensor) -> Image.Image:
    x = x.detach().cpu()
    if x.dim() == 4:
        x = x[0]
    x = (x * std + mean).clamp(0, 1)
    x = (x.permute(1,2,0).numpy() * 255).astype(np.uint8)
    return Image.fromarray(x)

def crop_from_tensor_and_feat(img_tensor_norm: torch.Tensor,
                              feat_single: torch.Tensor,
                              channel_id: int,
                              frac: float = 0.25) -> Image.Image:
    img = (img_tensor_norm.detach().cpu() * std + mean).clamp(0, 1)
    img_np = (img.permute(1,2,0).numpy() * 255).astype(np.uint8)
    H, W = img_np.shape[:2]

    act = feat_single[channel_id].detach().cpu().clamp(min=0)  # [h,w]
    h, w = act.shape

    flat = int(torch.argmax(act).item())
    iy, ix = flat // w, flat % w

    cy = int((iy + 0.5) * H / h)
    cx = int((ix + 0.5) * W / w)

    ch, cw = int(H * frac), int(W * frac)
    y0 = max(0, cy - ch // 2); y1 = min(H, y0 + ch)
    x0 = max(0, cx - cw // 2); x1 = min(W, x0 + cw)

    return Image.fromarray(img_np[y0:y1, x0:x1])

# %%
# Core scoring helper

@torch.no_grad()
def reduce_all_channels(feat: torch.Tensor, reduction: str) -> torch.Tensor:
    # feat: [B,C,h,w] -> [B,C]
    if reduction == "max":
        return feat.amax(dim=(2,3))
    elif reduction == "mean":
        return feat.mean(dim=(2,3))
    else:
      raise ValueError("reduction must be 'max' or 'mean'")

# %%
# Pass 1: scan dataset once

CKPT_PATH = "/content/drive/MyDrive/topk_scan_ckpt.pkl"
SAVE_EVERY = 1000

def save_ckpt(path, step, heaps, ch0, ch1):
    with open(path, "wb") as f:
        pkl.dump({"step": step, "heaps": heaps, "ch0": ch0, "ch1": ch1}, f)

def load_ckpt(path):
    if os.path.exists(path):
        with open(path, "rb") as f:
            return pkl.load(f)
    return None

def scan_topk_keys(model, dl_train, device, layer_name: str,
                   channel_start: int, channel_end_inclusive: int,
                   topk: int, heap_batch: int, reduction: str):
    activation = {}

    def hook_fn(module, inp, out):
        activation["feat"] = out

    layer = dict(model.named_modules())[layer_name]
    handle = layer.register_forward_hook(hook_fn)

    model.eval()

    heaps = None
    ch0 = None
    ch1 = None
    start_step = 0  # ✅ define default

    # load checkpoint if exists
    ckpt = load_ckpt(CKPT_PATH)
    if ckpt is not None:
        start_step = int(ckpt["step"]) + 1
        heaps = ckpt["heaps"]
        ch0 = int(ckpt["ch0"])
        ch1 = int(ckpt["ch1"])
        print(f"Resuming from batch {start_step} (range [{ch0}, {ch1}])")

    last_step = None

    with torch.no_grad():
        for step, (imgs, keys) in enumerate(dl_train):

            # skip already-processed batches when resuming
            if step < start_step:
                continue

            last_step = step

            imgs = imgs.to(device, non_blocking=True)

            use_cuda = imgs.is_cuda
            with torch.amp.autocast(device_type="cuda", enabled=use_cuda):
                _ = model(imgs)

            feat = activation["feat"]  # [B,C,h,w]
            B, C = feat.shape[0], feat.shape[1]

            if heaps is None:
                # clamp channel range to available channels
                ch0 = max(0, int(channel_start))
                ch1 = min(C - 1, int(channel_end_inclusive))
                if ch0 > ch1:
                    handle.remove()
                    raise ValueError(f"Invalid channel range after clamping: [{ch0}, {ch1}] with C={C}")

                heaps = {c: [] for c in range(ch0, ch1 + 1)}
                print(f"Scanning layer={layer_name} channels={C} using range [{ch0}, {ch1}]")

            else:
                # sanity clamp if resuming from ckpt created with same layer
                ch0 = max(0, min(ch0, C - 1))
                ch1 = max(0, min(ch1, C - 1))
                if ch0 > ch1:
                    handle.remove()
                    raise ValueError(f"Checkpoint channel range invalid for this run: [{ch0}, {ch1}] with C={C}")

            scores_bc = reduce_all_channels(feat, reduction).float()  # [B,C]
            scores_sel = scores_bc[:, ch0:ch1+1]                      # [B,Cr]

            k = min(heap_batch, B)
            vals, idxs = torch.topk(scores_sel, k=k, dim=0)           # [k,Cr]

            vals = vals.detach().cpu()
            idxs = idxs.detach().cpu()

            # update heaps
            for offset, c in enumerate(range(ch0, ch1 + 1)):
                h = heaps[c]
                for j in range(k):
                    v = float(vals[j, offset].item())
                    i = int(idxs[j, offset].item())
                    key = keys[i]

                    item = (v, key)
                    if len(h) < topk:
                        heapq.heappush(h, item)
                    else:
                        if v > h[0][0]:
                            heapq.heapreplace(h, item)

            if (step + 1) % 50 == 0:
                sample_c = ch0
                if heaps[sample_c]:
                    print(f"Scanning batches={step+1} ch{sample_c} min_top{topk}={heaps[sample_c][0][0]:.4f}")

            # periodic checkpoint save
            if (step + 1) % SAVE_EVERY == 0:
                save_ckpt(CKPT_PATH, step, heaps, ch0, ch1)
                print(f"ckpt saved at batch {step}")

    handle.remove()

    # final checkpoint save
    if heaps is not None and last_step is not None:
        save_ckpt(CKPT_PATH, last_step, heaps, ch0, ch1)
        print(f"ckpt final save at batch {last_step}")

    # finalize sorted lists
    topk_by_channel = {c: sorted(h, key=lambda x: x[0], reverse=True) for c, h in heaps.items()}
    return topk_by_channel

# %%
# Pass 2: save images to disk/Drive

def map_top_keys(topk_by_channel):
    wanted_keys = set()
    key_to_targets = {}  # key -> list[(channel, score, rank)]

    for c, items in topk_by_channel.items():
        # items are already sorted desc in your code
        for rank, (score, key) in enumerate(items, start=1):
            wanted_keys.add(key)
            key_to_targets.setdefault(key, []).append((c, float(score), rank))

    return wanted_keys, key_to_targets

def _safe_filename(s: str, max_len: int = 120) -> str:
    s = str(s).replace("/", "_").replace("\\", "_")
    s = re.sub(r"[^a-zA-Z0-9._-]+", "_", s)
    return s[:max_len]

@torch.no_grad()

def save_topk_images_wds_streaming(
    model, dl_train, device,
    layer_name: str,
    topk_by_channel: dict,
    out_root: str,
    crop_frac: float,
):
    # Build wanted maps
    wanted_keys, key_to_targets = map_top_keys(topk_by_channel)
    remaining = set(wanted_keys)

    # Hook
    activation = {}
    def hook_fn(module, inp, out):
        activation["feat"] = out

    layer = dict(model.named_modules())[layer_name]
    handle = layer.register_forward_hook(hook_fn)

    layer_dir = os.path.join(out_root, layer_name)
    os.makedirs(layer_dir, exist_ok=True)

    model.eval()

    for step, (imgs, keys) in enumerate(dl_train):
        imgs = imgs.to(device, non_blocking=True)

        use_cuda = imgs.is_cuda
        with torch.amp.autocast(device_type="cuda", enabled=use_cuda):
            _ = model(imgs)

        feat = activation["feat"]  # [B,C,h,w]

        # Search the indices we need in this batch
        hit_indices = [i for i, k in enumerate(keys) if k in remaining]
        if not hit_indices:
            if (step + 1) % 200 == 0:
                print(f"batches={step+1} remaining={len(remaining)}")
            continue

        for i in hit_indices:
            key = keys[i]
            key_safe = _safe_filename(key)

            # produce PIL images once per sample
            pil_full = tensor_to_pil(imgs[i])
            # crop depends on channel, so we’ll compute per channel

            # save for all channels that want this key
            for (c, score, rank) in key_to_targets[key]:
                ch_dir = os.path.join(layer_dir, f"ch_{c:04d}")
                os.makedirs(ch_dir, exist_ok=True)

                pil_crop = crop_from_tensor_and_feat(imgs[i], feat[i], c, frac=crop_frac)

                pil_full.save(os.path.join(ch_dir, f"rank{rank:02d}_FULL_score{score:.4f}_{key_safe}.jpg"))
                pil_crop.save(os.path.join(ch_dir, f"rank{rank:02d}_CROP_score{score:.4f}_{key_safe}.jpg"))

            remaining.remove(key)

        if (step + 1) % 50 == 0:
            print(f"batches={step+1} saved={(len(wanted_keys)-len(remaining))}/{len(wanted_keys)} remaining={len(remaining)}")

        # Early exit when done
        if not remaining:
            print(f"Done early at batch {step+1}")
            break

    handle.remove()
    print("Done ->", layer_dir)

# %%
# Run

topk_by_channel = scan_topk_keys(
    model=model,
    dl_train=dl_train,
    device=device,
    layer_name=CFG["LAYER_NAME"],
    channel_start=CFG["CHANNEL_START"],
    channel_end_inclusive=CFG["CHANNEL_END"],
    topk=CFG["TOPK"],
    heap_batch=CFG["HEAP_BATCH"],
    reduction=CFG["REDUCTION"],
)

save_topk_images_wds_streaming(
    model=model,
    dl_train=dl_train,
    device=device,
    layer_name=CFG["LAYER_NAME"],
    topk_by_channel=topk_by_channel,
    out_root=CFG["OUT_ROOT"],
    crop_frac=CFG["CROP_FRAC"],
)
# Out:
# Scanning layer=mixed4e channels=832 using range [0, 831]
# Scanning batches=50 ch0 min_top10=97.0000
# Scanning batches=100 ch0 min_top10=98.5625
# Scanning batches=150 ch0 min_top10=100.8125
# Scanning batches=200 ch0 min_top10=102.0000
# Scanning batches=250 ch0 min_top10=107.7500
# Scanning batches=300 ch0 min_top10=108.1875
# Scanning batches=350 ch0 min_top10=110.1875
# Scanning batches=400 ch0 min_top10=112.0000
# Scanning batches=450 ch0 min_top10=112.6250
# Scanning batches=500 ch0 min_top10=116.0000
# Scanning batches=550 ch0 min_top10=116.9375
# Scanning batches=600 ch0 min_top10=116.9375
# Scanning batches=650 ch0 min_top10=119.6875
# Scanning batches=700 ch0 min_top10=119.6875
# Scanning batches=750 ch0 min_top10=119.6875
# Scanning batches=800 ch0 min_top10=120.0625
# Scanning batches=850 ch0 min_top10=120.0625
# Scanning batches=900 ch0 min_top10=120.2500
# Scanning batches=950 ch0 min_top10=120.3750
# Scanning batches=1000 ch0 min_top10=124.1875
# ckpt saved at batch 999
# Scanning batches=1050 ch0 min_top10=124.1875
# Scanning batches=1100 ch0 min_top10=124.1875
# Scanning batches=1150 ch0 min_top10=125.4375
# Scanning batches=1200 ch0 min_top10=125.4375
# Scanning batches=1250 ch0 min_top10=125.9375
# Scanning batches=1300 ch0 min_top10=125.9375
# Scanning batches=1350 ch0 min_top10=125.9375
# Scanning batches=1400 ch0 min_top10=125.9375
# Scanning batches=1450 ch0 min_top10=127.3125
# Scanning batches=1500 ch0 min_top10=127.3125
# Scanning batches=1550 ch0 min_top10=127.3125
# Scanning batches=1600 ch0 min_top10=127.3125
# Scanning batches=1650 ch0 min_top10=127.3125
# Scanning batches=1700 ch0 min_top10=127.3125
# Scanning batches=1750 ch0 min_top10=127.3125
# Scanning batches=1800 ch0 min_top10=127.3125
# Scanning batches=1850 ch0 min_top10=127.3125
# Scanning batches=1900 ch0 min_top10=129.3750
# Scanning batches=1950 ch0 min_top10=130.3750
# Scanning batches=2000 ch0 min_top10=130.3750
# ckpt saved at batch 1999
# Scanning batches=2050 ch0 min_top10=130.3750
# Scanning batches=2100 ch0 min_top10=130.3750
# Scanning batches=2150 ch0 min_top10=130.3750
# Scanning batches=2200 ch0 min_top10=130.3750
# Scanning batches=2250 ch0 min_top10=130.3750
# Scanning batches=2300 ch0 min_top10=130.3750
# Scanning batches=2350 ch0 min_top10=130.3750
# Scanning batches=2400 ch0 min_top10=130.3750
# Scanning batches=2450 ch0 min_top10=130.3750
# Scanning batches=2500 ch0 min_top10=130.3750
# Scanning batches=2550 ch0 min_top10=130.5000
# Scanning batches=2600 ch0 min_top10=130.6250
# Scanning batches=2650 ch0 min_top10=132.7500
# Scanning batches=2700 ch0 min_top10=132.7500
# Scanning batches=2750 ch0 min_top10=133.5000
# Scanning batches=2800 ch0 min_top10=133.5000
# Scanning batches=2850 ch0 min_top10=133.5000
# Scanning batches=2900 ch0 min_top10=133.5000
# Scanning batches=2950 ch0 min_top10=133.5000
# Scanning batches=3000 ch0 min_top10=133.5000
# ckpt saved at batch 2999
# Scanning batches=3050 ch0 min_top10=133.5000
# Scanning batches=3100 ch0 min_top10=133.5000
# Scanning batches=3150 ch0 min_top10=133.5000
# Scanning batches=3200 ch0 min_top10=133.5000
# Scanning batches=3250 ch0 min_top10=133.5000
# Scanning batches=3300 ch0 min_top10=133.5000
# Scanning batches=3350 ch0 min_top10=133.5000
# Scanning batches=3400 ch0 min_top10=133.5000
# Scanning batches=3450 ch0 min_top10=133.5000
# Scanning batches=3500 ch0 min_top10=135.1250
# Scanning batches=3550 ch0 min_top10=135.1250
# Scanning batches=3600 ch0 min_top10=135.7500
# Scanning batches=3650 ch0 min_top10=135.7500
# Scanning batches=3700 ch0 min_top10=135.7500
# Scanning batches=3750 ch0 min_top10=135.7500
# Scanning batches=3800 ch0 min_top10=135.7500
# Scanning batches=3850 ch0 min_top10=135.7500
# Scanning batches=3900 ch0 min_top10=135.7500
# Scanning batches=3950 ch0 min_top10=135.7500
# Scanning batches=4000 ch0 min_top10=135.7500
# ckpt saved at batch 3999
# Scanning batches=4050 ch0 min_top10=135.7500
# Scanning batches=4100 ch0 min_top10=135.7500
# Scanning batches=4150 ch0 min_top10=136.0000
# Scanning batches=4200 ch0 min_top10=136.0000
# Scanning batches=4250 ch0 min_top10=136.0000
# Scanning batches=4300 ch0 min_top10=136.0000
# Scanning batches=4350 ch0 min_top10=136.0000
# Scanning batches=4400 ch0 min_top10=136.0000
# Scanning batches=4450 ch0 min_top10=136.0000
# Scanning batches=4500 ch0 min_top10=136.0000
# Scanning batches=4550 ch0 min_top10=136.0000
# Scanning batches=4600 ch0 min_top10=136.0000
# Scanning batches=4650 ch0 min_top10=136.0000
# Scanning batches=4700 ch0 min_top10=136.1250
# Scanning batches=4750 ch0 min_top10=136.1250
# Scanning batches=4800 ch0 min_top10=136.1250
# Scanning batches=4850 ch0 min_top10=136.1250
# Scanning batches=4900 ch0 min_top10=136.1250
# Scanning batches=4950 ch0 min_top10=136.1250
# Scanning batches=5000 ch0 min_top10=136.1250
# ckpt saved at batch 4999
# Scanning batches=5050 ch0 min_top10=136.1250
# Scanning batches=5100 ch0 min_top10=137.5000
# Scanning batches=5150 ch0 min_top10=137.5000
# Scanning batches=5200 ch0 min_top10=137.5000
# Scanning batches=5250 ch0 min_top10=137.5000
# Scanning batches=5300 ch0 min_top10=137.5000
# Scanning batches=5350 ch0 min_top10=137.5000
# Scanning batches=5400 ch0 min_top10=138.3750
# Scanning batches=5450 ch0 min_top10=138.3750
# Scanning batches=5500 ch0 min_top10=138.3750
# Scanning batches=5550 ch0 min_top10=138.3750
# Scanning batches=5600 ch0 min_top10=138.3750
# Scanning batches=5650 ch0 min_top10=138.3750
# Scanning batches=5700 ch0 min_top10=138.3750
# Scanning batches=5750 ch0 min_top10=138.3750
# Scanning batches=5800 ch0 min_top10=138.3750
# Scanning batches=5850 ch0 min_top10=138.3750
# Scanning batches=5900 ch0 min_top10=138.3750
# Scanning batches=5950 ch0 min_top10=138.3750
# Scanning batches=6000 ch0 min_top10=138.3750
# ckpt saved at batch 5999
# Scanning batches=6050 ch0 min_top10=138.3750
# Scanning batches=6100 ch0 min_top10=138.3750
# Scanning batches=6150 ch0 min_top10=138.3750
# Scanning batches=6200 ch0 min_top10=138.3750
# Scanning batches=6250 ch0 min_top10=139.7500
# Scanning batches=6300 ch0 min_top10=139.7500
# Scanning batches=6350 ch0 min_top10=139.7500
# Scanning batches=6400 ch0 min_top10=139.7500
# Scanning batches=6450 ch0 min_top10=139.7500
# Scanning batches=6500 ch0 min_top10=139.7500
# Scanning batches=6550 ch0 min_top10=139.7500
# Scanning batches=6600 ch0 min_top10=139.7500
# Scanning batches=6650 ch0 min_top10=139.7500
# Scanning batches=6700 ch0 min_top10=139.7500
# Scanning batches=6750 ch0 min_top10=139.7500
# Scanning batches=6800 ch0 min_top10=139.7500
# Scanning batches=6850 ch0 min_top10=139.7500
# Scanning batches=6900 ch0 min_top10=139.7500
# Scanning batches=6950 ch0 min_top10=139.7500
# Scanning batches=7000 ch0 min_top10=139.7500
# ckpt saved at batch 6999
# Scanning batches=7050 ch0 min_top10=139.7500
# Scanning batches=7100 ch0 min_top10=139.7500
# Scanning batches=7150 ch0 min_top10=139.7500
# Scanning batches=7200 ch0 min_top10=139.7500
# Scanning batches=7250 ch0 min_top10=139.7500
# Scanning batches=7300 ch0 min_top10=139.7500
# Scanning batches=7350 ch0 min_top10=139.7500
# Scanning batches=7400 ch0 min_top10=139.7500
# Scanning batches=7450 ch0 min_top10=139.7500
# Scanning batches=7500 ch0 min_top10=139.7500
# Scanning batches=7550 ch0 min_top10=140.2500
# Scanning batches=7600 ch0 min_top10=140.2500
# Scanning batches=7650 ch0 min_top10=140.2500
# Scanning batches=7700 ch0 min_top10=140.2500
# Scanning batches=7750 ch0 min_top10=140.2500
# Scanning batches=7800 ch0 min_top10=140.2500
# Scanning batches=7850 ch0 min_top10=140.2500
# Scanning batches=7900 ch0 min_top10=140.2500
# Scanning batches=7950 ch0 min_top10=140.2500
# Scanning batches=8000 ch0 min_top10=140.2500
# ckpt saved at batch 7999
# Scanning batches=8050 ch0 min_top10=140.2500
# Scanning batches=8100 ch0 min_top10=140.2500
# Scanning batches=8150 ch0 min_top10=140.2500
# Scanning batches=8200 ch0 min_top10=140.2500
# Scanning batches=8250 ch0 min_top10=140.2500
# Scanning batches=8300 ch0 min_top10=140.2500
# Scanning batches=8350 ch0 min_top10=140.2500
# Scanning batches=8400 ch0 min_top10=140.2500
# Scanning batches=8450 ch0 min_top10=140.2500
# Scanning batches=8500 ch0 min_top10=140.2500
# Scanning batches=8550 ch0 min_top10=140.2500
# Scanning batches=8600 ch0 min_top10=140.2500
# Scanning batches=8650 ch0 min_top10=140.2500
# Scanning batches=8700 ch0 min_top10=140.2500
# Scanning batches=8750 ch0 min_top10=140.2500
# Scanning batches=8800 ch0 min_top10=140.2500
# Scanning batches=8850 ch0 min_top10=140.2500
# Scanning batches=8900 ch0 min_top10=140.2500
# Scanning batches=8950 ch0 min_top10=140.2500
# Scanning batches=9000 ch0 min_top10=140.2500
# ckpt saved at batch 8999
# Scanning batches=9050 ch0 min_top10=140.2500
# Scanning batches=9100 ch0 min_top10=140.2500
# Scanning batches=9150 ch0 min_top10=140.2500
# Scanning batches=9200 ch0 min_top10=140.2500
# Scanning batches=9250 ch0 min_top10=140.2500
# Scanning batches=9300 ch0 min_top10=140.2500
# Scanning batches=9350 ch0 min_top10=140.2500
# Scanning batches=9400 ch0 min_top10=140.2500
# Scanning batches=9450 ch0 min_top10=141.3750
# Scanning batches=9500 ch0 min_top10=141.3750
# Scanning batches=9550 ch0 min_top10=141.3750
# Scanning batches=9600 ch0 min_top10=141.3750
# Scanning batches=9650 ch0 min_top10=141.3750
# Scanning batches=9700 ch0 min_top10=141.3750
# Scanning batches=9750 ch0 min_top10=141.3750
# Scanning batches=9800 ch0 min_top10=141.3750
# Scanning batches=9850 ch0 min_top10=141.3750
# Scanning batches=9900 ch0 min_top10=143.1250
# Scanning batches=9950 ch0 min_top10=143.1250
# Scanning batches=10000 ch0 min_top10=143.1250
# ckpt saved at batch 9999
# ckpt final save at batch 10009
# batches=150 saved=118/6115 remaining=5997
# batches=200 remaining=5959
# batches=400 saved=281/6115 remaining=5834
# batches=450 saved=316/6115 remaining=5799
# batches=500 saved=348/6115 remaining=5767
# batches=600 remaining=5698
# batches=650 saved=451/6115 remaining=5664
# batches=800 remaining=5581
# batches=900 saved=599/6115 remaining=5516
# batches=950 saved=632/6115 remaining=5483
# batches=1000 saved=660/6115 remaining=5455
# batches=1050 saved=693/6115 remaining=5422
# batches=1200 saved=762/6115 remaining=5353
# batches=1300 saved=825/6115 remaining=5290
# batches=1350 saved=846/6115 remaining=5269
# batches=1400 saved=880/6115 remaining=5235
# batches=1450 saved=908/6115 remaining=5207
# batches=1500 saved=936/6115 remaining=5179
# batches=1550 saved=968/6115 remaining=5147
# batches=1600 saved=999/6115 remaining=5116
# batches=1650 saved=1026/6115 remaining=5089
# batches=1800 remaining=5011
# batches=1900 saved=1165/6115 remaining=4950
# batches=2000 saved=1242/6115 remaining=4873
# batches=2100 saved=1297/6115 remaining=4818
# batches=2150 saved=1330/6115 remaining=4785
# batches=2200 remaining=4759
# batches=2350 saved=1432/6115 remaining=4683
# batches=2400 remaining=4663
# batches=2600 saved=1577/6115 remaining=4538
# batches=2700 saved=1630/6115 remaining=4485
# batches=2750 saved=1668/6115 remaining=4447
# batches=2800 saved=1685/6115 remaining=4430
# batches=2900 saved=1736/6115 remaining=4379
# batches=3000 saved=1804/6115 remaining=4311
# batches=3100 saved=1853/6115 remaining=4262
# batches=3200 saved=1919/6115 remaining=4196
# batches=3350 saved=2023/6115 remaining=4092
# batches=3400 remaining=4058
# batches=3450 saved=2092/6115 remaining=4023
# batches=3500 saved=2127/6115 remaining=3988
# batches=3550 saved=2153/6115 remaining=3962
# batches=3600 remaining=3931
# batches=3700 saved=2247/6115 remaining=3868
# batches=3750 saved=2275/6115 remaining=3840
# batches=3800 remaining=3808
# batches=3950 saved=2400/6115 remaining=3715
# batches=4000 saved=2449/6115 remaining=3666
# batches=4050 saved=2480/6115 remaining=3635
# batches=4100 saved=2505/6115 remaining=3610
# batches=4200 saved=2567/6115 remaining=3548
# batches=4300 saved=2642/6115 remaining=3473
# batches=4350 saved=2659/6115 remaining=3456
# batches=4400 saved=2688/6115 remaining=3427
# batches=4550 saved=2758/6115 remaining=3357
# batches=4600 saved=2793/6115 remaining=3322
# batches=4650 saved=2829/6115 remaining=3286
# batches=4700 saved=2859/6115 remaining=3256
# batches=4800 saved=2916/6115 remaining=3199
# batches=4950 saved=3005/6115 remaining=3110
# batches=5000 remaining=3080
# batches=5150 saved=3113/6115 remaining=3002
# batches=5200 saved=3144/6115 remaining=2971
# batches=5350 saved=3224/6115 remaining=2891
# batches=5400 saved=3256/6115 remaining=2859
# batches=5600 remaining=2723
# batches=5650 saved=3415/6115 remaining=2700
# batches=5700 saved=3450/6115 remaining=2665
# batches=5750 saved=3478/6115 remaining=2637
# batches=5800 remaining=2608
# batches=5900 saved=3577/6115 remaining=2538
# batches=6000 remaining=2484
# batches=6100 saved=3698/6115 remaining=2417
# batches=6150 saved=3728/6115 remaining=2387
# batches=6200 saved=3759/6115 remaining=2356
# batches=6250 saved=3784/6115 remaining=2331
# batches=6400 saved=3874/6115 remaining=2241
# batches=6450 saved=3903/6115 remaining=2212
# batches=6550 saved=3964/6115 remaining=2151
# batches=6600 saved=3990/6115 remaining=2125
# batches=6650 saved=4023/6115 remaining=2092
# batches=6700 saved=4055/6115 remaining=2060
# batches=6750 saved=4083/6115 remaining=2032
# batches=6800 saved=4112/6115 remaining=2003
# batches=6850 saved=4144/6115 remaining=1971
# batches=7000 remaining=1872
# batches=7050 saved=4279/6115 remaining=1836
# batches=7100 saved=4308/6115 remaining=1807
# batches=7200 saved=4372/6115 remaining=1743
# batches=7250 saved=4403/6115 remaining=1712
# batches=7400 remaining=1624
# batches=7600 saved=4612/6115 remaining=1503
# batches=7750 saved=4707/6115 remaining=1408
# batches=7800 saved=4734/6115 remaining=1381
# batches=8000 remaining=1259
# batches=8050 saved=4888/6115 remaining=1227
# batches=8150 saved=4949/6115 remaining=1166
# batches=8200 remaining=1148
# batches=8300 saved=5007/6115 remaining=1108
# batches=8350 saved=5041/6115 remaining=1074
# batches=8400 remaining=1040
# batches=8450 saved=5106/6115 remaining=1009
# batches=8550 saved=5165/6115 remaining=950
# batches=8600 remaining=909
# batches=8650 saved=5250/6115 remaining=865
# batches=8700 saved=5290/6115 remaining=825
# batches=8800 saved=5351/6115 remaining=764
# batches=8850 saved=5379/6115 remaining=736
# batches=8950 saved=5448/6115 remaining=667
# batches=9000 saved=5478/6115 remaining=637
# batches=9050 saved=5513/6115 remaining=602
# batches=9100 saved=5548/6115 remaining=567
# batches=9150 saved=5581/6115 remaining=534
# batches=9200 saved=5613/6115 remaining=502
# batches=9300 saved=5674/6115 remaining=441
# batches=9350 saved=5716/6115 remaining=399
# batches=9400 saved=5755/6115 remaining=360
# batches=9450 saved=5793/6115 remaining=322
# batches=9550 saved=5858/6115 remaining=257
# batches=9600 saved=5884/6115 remaining=231
# batches=9750 saved=5967/6115 remaining=148
# batches=9800 saved=5997/6115 remaining=118
# batches=9850 saved=6021/6115 remaining=94
# batches=10000 remaining=6
# Done early at batch 10008
# Done -> /content/drive/MyDrive/Dataset_images/mixed4e
